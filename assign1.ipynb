# %%
import PIL

# %%
from PIL import Image

# %%
image = Image.open('test.DNG')

# %%
image
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=160x120 at 0x2739A20A358>

# %%
image = image.convert('RGB')

# %%
new_image = Image.new(image.mode, (image.width, image.height))

# %%
pixels = new_image.load()

# %%
for i in range(image.width):
    for j in range(image.height):
        rr, gg, bb = image.getpixel((i, j))
        new_rr = rr * 0.1
        pixels[i,j] = (int(new_rr), gg, bb)

# %%
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=160x120 at 0x2739A307BA8>

# %%
new_text = Image.new(image.mode, (image.width, 75))

# %%
new_text
# Out:
# <PIL.Image.Image image mode=RGB size=160x75 at 0x2739A307278>

# %%
font PIL.ImageFont.truetype
